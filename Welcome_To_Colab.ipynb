# %% [markdown]
# <a href="https://colab.research.google.com/github/gp-8777/THEGP-GIT/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Python program

name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Hello,", name)
print("You are", age, "years old.")

if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# Enter your name: Gaurav
# Enter your age: 21
# Hello, Gaurav
# You are 21 years old.
# You are an adult.
